# %%
import pandas as pd
from dotenv import load_dotenv # type: ignore
import os
import sys
sys.path.append("..")
from src.get_all_files import get_all_files
from dateparser import parse
import cv2
import pytesseract
import io
from PIL import Image

# %%
load_dotenv()
blob_keys = os.getenv("AZURE_BLOB_KEYS")
all_files = get_all_files(blob_keys)
print(len(all_files))
# Out:
# 5123

# %%
def process_image(input_img_path, output_img_path, regions):
    img = cv2.imread(input_img_path)
    extracted_texts = {}

    for region_name, (x, y, w, h) in regions.items():
        # Dessiner les rectangles et noms des régions
        top_left = (x, y)
        bottom_right = (x + w, y + h)
        cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 2)

        # Extraire le texte de la région
        roi = img[y:y+h, x:x+w]
        text = pytesseract.image_to_string(roi, config="--psm 6")
        extracted_texts[region_name] = text.strip()

    # Sauvegarde de l'image annotée
    cv2.imwrite(output_img_path, img)

    return extracted_texts

# Définition des blocs
predefined_regions = {
    "Adresse": (10, 116, 400, 60),
    "Nom": (70, 70, 250, 30),
    "Mail": (50, 100, 250, 20),
    "Date": (105, 45, 250, 30),
    "Products": (20, 180, 400, 350),
    "Quantities_and_prices": (540, 180, 250, 350)
}

# %%
df = pd.DataFrame(columns=["adress", "nom", "mail", "date", "products", "quantities", "prices", "total"])

# %%
file = all_files[6]
chemin = f"../data/files/{file.split('_')[1]}/{file}"
output = "../data/test.png"

# Traitement de l'image
extracted_texts = process_image(chemin, output, predefined_regions)

# Affichage des résultats
print(extracted_texts)
print(f"adresse: {extracted_texts["Adresse"].replace("\n", " ")}")
print(f"nom: {extracted_texts["Nom"]}")
print(f"mail: {extracted_texts["Mail"]}")
print(f"date: {parse(extracted_texts["Date"], languages=["fr","en"])}")
print(f"products: {[product for product in extracted_texts["Products"].split('\n') if product != "TOTAL"]}")
print(f"quantities: {[quantity.split("x")[0].strip() for quantity in extracted_texts["Quantities_and_prices"].split('\n')[:-1]]}")
print(f"prices: {[price.split("x")[1].strip().replace(" Euro", "") for price in extracted_texts["Quantities_and_prices"].split('\n')[:-1]]}")
print(f"total: {extracted_texts["Quantities_and_prices"].split('\n')[-1].replace(" Euro", "")}")
# Out:
# {'Adresse': 'Address 96374 Amanda Dam\nEast Craigfort, FM 73373', 'Nom': 'Bruce Pace', 'Mail': 'alan46 @example.org:', 'Date': '2018-12-01', 'Products': 'These president network actually.\nTOTAL', 'Quantities_and_prices': '3x 7.30 Euro\n21.90 Euro'}
# adresse: Address 96374 Amanda Dam East Craigfort, FM 73373
# nom: Bruce Pace
# mail: alan46 @example.org:
# date: 2018-12-01 00:00:00
# products: ['These president network actually.']
# quantities: ['3']
# prices: ['7.30']
# total: 21.90

# %%
# Chargement des données extraites
file = all_files[500]
chemin = f"../data/files/{file.split('_')[1]}/{file}"
output = "../data/test.png"

extracted_texts = process_image(chemin, output, predefined_regions)

# Nettoyage et formatage des données
adresse = extracted_texts["Adresse"].replace("\n", " ")
nom_client = extracted_texts["Nom"]
mail_client = extracted_texts["Mail"]
date_facturation = parse(extracted_texts["Date"], languages=["fr", "en"])

products = [product for product in extracted_texts["Products"].split('\n') if product != "TOTAL"]
quantities = [quantity.split("x")[0].strip() for quantity in extracted_texts["Quantities_and_prices"].split('\n')[:-1]]
prices = [price.split("x")[1].strip().replace(" Euro", "") for price in extracted_texts["Quantities_and_prices"].split('\n')[:-1]]
total = extracted_texts["Quantities_and_prices"].split('\n')[-1].replace(" Euro", "")

# Génération d'identifiants uniques
id_client = f"CLT_{hash(nom_client + mail_client) % 10**6}"
id_facture = file.replace(".png","")

# DataFrame Client
df_client = pd.DataFrame({
    "id_client": [id_client],
    "Nom": [nom_client],
    "mail": [mail_client],
    "birthday": [None]  # Date de naissance inconnue ici
})

# DataFrame Facture
df_facture = pd.DataFrame({
    "id_facture": [id_facture],
    "texte": [adresse],
    "date_facturation": [date_facturation]
})

# DataFrame Produit
df_produit = pd.DataFrame({
    "Id_produit": [f"PROD_{hash(p) % 10**6}" for p in products],
    "Nom": products,
    "Prix": prices
})

# DataFrame Achat
df_achat = pd.DataFrame({
    "Id_produit": [f"PROD_{hash(p) % 10**6}" for p in products],
    "id_client": [id_client] * len(products),
    "id_facture": [id_facture] * len(products),
    "quantité": quantities
})

# Affichage des DataFrames
print("Clients:\n") 
display(df_client)
print("Factures:\n")
display(df_facture)
print("Produits:\n")
display(df_produit)
print("Achats:\n")
display(df_achat)
# Out:
# Clients:
#     id_client Nom                  mail birthday
# 0  CLT_410183      cindy? 2@example.com     None
# Factures:
#           id_facture                                    texte date_facturation
# 0  FAC_2019_0453-218  Address Unit 9777 Box 0560 DPO AP 29783             None
# Produits:
#     Id_produit                              Nom    Prix
# 0  PROD_998674      Health year especially she.  123.28
# 1  PROD_301269  Evidence perform get according.   13.31
# Achats:
#     Id_produit   id_client         id_facture quantité
# 0  PROD_998674  CLT_410183  FAC_2019_0453-218        3
# 1  PROD_301269  CLT_410183  FAC_2019_0453-218        1

# %%
df_clients = pd.DataFrame(columns=["id_client", "Nom", "mail", "birthday"])
df_factures = pd.DataFrame(columns=["id_facture", "texte", "date_facturation"])
df_produits = pd.DataFrame(columns=["Id_produit", "Nom", "Prix"])
df_achats = pd.DataFrame(columns=["Id_produit", "id_client", "id_facture", "quantité"])

def nettoyer_total(total):
    """Vérifie si le total est bien détecté (ne doit pas contenir 'x')"""
    if "x" in total:
        return None  # Erreur de détection
    return total.replace(" Euro", "")

def extraire_donnees(file):
    """Extrait et nettoie les données d'un fichier"""
    chemin = f"../data/files/{file.split('_')[1]}/{file}"
    output = "../data/test.png"

    try:
        extracted_texts = process_image(chemin, output, predefined_regions)
        
        # Nettoyage et formatage
        adresse = extracted_texts["Adresse"].replace("\n", " ")
        nom_client = extracted_texts["Nom"]
        mail_client = extracted_texts["Mail"]
        date_facturation = parse(extracted_texts["Date"], languages=["fr", "en"])

        products = [product for product in extracted_texts["Products"].split('\n') if product != "TOTAL"]
        quantities = [quantity.split("x")[0].strip() for quantity in extracted_texts["Quantities_and_prices"].split('\n')[:-1]]
        prices = [price.split("x")[1].strip().replace(" Euro", "") for price in extracted_texts["Quantities_and_prices"].split('\n')[:-1]]
        total = nettoyer_total(extracted_texts["Quantities_and_prices"].split('\n')[-1])

        # Vérification des erreurs
        erreurs = []
        if not nom_client: erreurs.append("Nom non détecté")
        if not mail_client: erreurs.append("Mail non détecté")
        if not date_facturation: erreurs.append("Date non détectée")
        if not products: erreurs.append("Produits non détectés")
        if not quantities: erreurs.append("Quantités non détectées")
        if not prices: erreurs.append("Prix non détectés")
        if total is None: erreurs.append("Total mal détecté")

        if erreurs:
            print(f"Erreur dans le fichier {file} : {', '.join(erreurs)}")
            return None  # On saute ce fichier en cas d'erreur

        # Génération d'identifiants uniques
        id_client = f"CLT_{hash(nom_client + mail_client) % 10**6}"
        id_facture = f"FACT_{hash(file) % 10**6}"

        # Création des DataFrames temporaires
        df_client = pd.DataFrame([{
            "id_client": id_client,
            "Nom": nom_client,
            "mail": mail_client,
            "birthday": None
        }])

        df_facture = pd.DataFrame([{
            "id_facture": id_facture,
            "texte": adresse,
            "date_facturation": date_facturation
        }])

        df_produit = pd.DataFrame({
            "Id_produit": [f"PROD_{hash(p) % 10**6}" for p in products],
            "Nom": products,
            "Prix": prices
        })

        df_achat = pd.DataFrame({
            "Id_produit": [f"PROD_{hash(p) % 10**6}" for p in products],
            "id_client": [id_client] * len(products),
            "id_facture": [id_facture] * len(products),
            "quantité": quantities
        })

        return df_client, df_facture, df_produit, df_achat

    except Exception as e:
        print(f"Échec pour le fichier {file} : {str(e)}")
        return None

# Boucle sur les 500 premiers fichiers
for file in all_files[:500]:
    data = extraire_donnees(file)
    
    if data:
        df_client, df_facture, df_produit, df_achat = data

        # Ajout aux DataFrames globaux
        df_clients = pd.concat([df_clients, df_client], ignore_index=True)
        df_factures = pd.concat([df_factures, df_facture], ignore_index=True)
        df_produits = pd.concat([df_produits, df_produit], ignore_index=True)
        df_achats = pd.concat([df_achats, df_achat], ignore_index=True)

# Affichage final des DataFrames après traitement
print("\n✅ Traitement terminé. Voici les DataFrames finaux :")

print("Clients :")
display(df_clients)

print("Factures :")
display(df_factures)

print("Produits :")
display(df_produits)

print("Achats :")
display(df_achats)
# Out:
# Échec pour le fichier FAC_2018_0001-654.png : list index out of range
# C:\Users\melos\AppData\Local\Temp\ipykernel_23172\3984375533.py:91: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_factures = pd.concat([df_factures, df_facture], ignore_index=True)
# Erreur dans le fichier FAC_2018_0003-025.png : Total mal détecté
# Échec pour le fichier FAC_2018_0004-759.png : All arrays must be of the same length
# Erreur dans le fichier FAC_2018_0005-281.png : Date non détectée
# Échec pour le fichier FAC_2018_0006-250.png : list index out of range
# Erreur dans le fichier FAC_2018_0009-754.png : Nom non détecté
# Erreur dans le fichier FAC_2018_0010-104.png : Nom non détecté
# Échec pour le fichier FAC_2018_0011-692.png : All arrays must be of the same length
# Échec pour le fichier FAC_2018_0012-758.png : list index out of range
# Échec pour le fichier FAC_2018_0013-913.png : All arrays must be of the same length
# Échec pour le fichier FAC_2018_0014-558.png : All arrays must be of the same length
# Erreur dans le fichier FAC_2018_0015-089.png : Total mal détecté
# Échec pour le fichier FAC_2018_0016-604.png : list index out of range
# Erreur dans le fichier FAC_2018_0017-432.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2018_0018-032.png : Date non détectée
# Échec pour le fichier FAC_2018_0019-030.png : list index out of range
# Erreur dans le fichier FAC_2018_0020-095.png : Date non détectée
# Erreur dans le fichier FAC_2018_0022-238.png : Date non détectée
# Échec pour le fichier FAC_2018_0023-517.png : list index out of range
# Échec pour le fichier FAC_2018_0025-027.png : list index out of range
# Échec pour le fichier FAC_2018_0026-574.png : list index out of range
# Erreur dans le fichier FAC_2018_0027-203.png : Date non détectée
# Échec pour le fichier FAC_2018_0028-733.png : list index out of range
# Échec pour le fichier FAC_2018_0029-665.png : list index out of range
# Échec pour le fichier FAC_2018_0030-718.png : list index out of range
# Erreur dans le fichier FAC_2018_0031-558.png : Date non détectée
# Échec pour le fichier FAC_2018_0032-429.png : list index out of range
# Erreur dans le fichier FAC_2018_0033-225.png : Nom non détecté, Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2018_0036-284.png : All arrays must be of the same length
# Échec pour le fichier FAC_2018_0037-828.png : list index out of range
# Échec pour le fichier FAC_2018_0038-890.png : list index out of range
# Erreur dans le fichier FAC_2018_0039-006.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2018_0040-777.png : Nom non détecté, Quantités non détectées, Prix non détectés, Total mal détecté
# Erreur dans le fichier FAC_2018_0041-825.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2018_0042-163.png : Date non détectée
# Erreur dans le fichier FAC_2018_0043-714.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2018_0044-432.png : Nom non détecté, Date non détectée
# Échec pour le fichier FAC_2018_0045-348.png : list index out of range
# Échec pour le fichier FAC_2018_0046-284.png : list index out of range
# Échec pour le fichier FAC_2018_0047-159.png : All arrays must be of the same length
# Échec pour le fichier FAC_2018_0048-220.png : list index out of range
# Échec pour le fichier FAC_2019_0001-980.png : list index out of range
# Erreur dans le fichier FAC_2019_0006-389.png : Nom non détecté, Total mal détecté
# Échec pour le fichier FAC_2019_0008-367.png : list index out of range
# Erreur dans le fichier FAC_2019_0010-352.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0011-618.png : Total mal détecté
# Échec pour le fichier FAC_2019_0012-270.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0014-044.png : list index out of range
# Échec pour le fichier FAC_2019_0019-996.png : list index out of range
# Erreur dans le fichier FAC_2019_0020-944.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0021-387.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0022-080.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0023-565.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2019_0024-300.png : Date non détectée
# Erreur dans le fichier FAC_2019_0025-849.png : Nom non détecté, Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0026-643.png : Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0027-633.png : list index out of range
# Erreur dans le fichier FAC_2019_0028-906.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0029-882.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0030-370.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0031-591.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0032-196.png : Total mal détecté
# Échec pour le fichier FAC_2019_0033-721.png : list index out of range
# Erreur dans le fichier FAC_2019_0034-071.png : Date non détectée
# Échec pour le fichier FAC_2019_0035-046.png : list index out of range
# Erreur dans le fichier FAC_2019_0036-677.png : Date non détectée
# Échec pour le fichier FAC_2019_0037-233.png : list index out of range
# Erreur dans le fichier FAC_2019_0038-791.png : Total mal détecté
# Échec pour le fichier FAC_2019_0039-296.png : list index out of range
# Erreur dans le fichier FAC_2019_0040-081.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0041-875.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0043-887.png : Date non détectée
# Erreur dans le fichier FAC_2019_0044-103.png : Date non détectée
# Échec pour le fichier FAC_2019_0045-389.png : list index out of range
# Erreur dans le fichier FAC_2019_0046-284.png : Date non détectée
# Erreur dans le fichier FAC_2019_0047-464.png : Date non détectée
# Erreur dans le fichier FAC_2019_0048-650.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2019_0052-379.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0053-363.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2019_0054-214.png : Date non détectée
# Erreur dans le fichier FAC_2019_0055-686.png : Nom non détecté, Date non détectée, Quantités non détectées, Prix non détectés, Total mal détecté
# Échec pour le fichier FAC_2019_0057-718.png : list index out of range
# Échec pour le fichier FAC_2019_0061-073.png : list index out of range
# Échec pour le fichier FAC_2019_0062-623.png : list index out of range
# Erreur dans le fichier FAC_2019_0063-650.png : Total mal détecté
# Échec pour le fichier FAC_2019_0065-546.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0066-746.png : list index out of range
# Échec pour le fichier FAC_2019_0068-167.png : list index out of range
# Erreur dans le fichier FAC_2019_0069-473.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0070-388.png : Date non détectée
# Erreur dans le fichier FAC_2019_0071-276.png : Nom non détecté
# Échec pour le fichier FAC_2019_0072-947.png : list index out of range
# Échec pour le fichier FAC_2019_0073-655.png : list index out of range
# Échec pour le fichier FAC_2019_0075-570.png : list index out of range
# Échec pour le fichier FAC_2019_0076-224.png : list index out of range
# Échec pour le fichier FAC_2019_0077-701.png : list index out of range
# Échec pour le fichier FAC_2019_0078-332.png : list index out of range
# Échec pour le fichier FAC_2019_0081-794.png : list index out of range
# Échec pour le fichier FAC_2019_0082-057.png : list index out of range
# Erreur dans le fichier FAC_2019_0083-234.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0086-824.png : Nom non détecté, Total mal détecté
# Erreur dans le fichier FAC_2019_0087-323.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2019_0088-410.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2019_0089-274.png : Nom non détecté, Date non détectée
# Échec pour le fichier FAC_2019_0090-067.png : list index out of range
# Erreur dans le fichier FAC_2019_0091-216.png : Date non détectée
# Erreur dans le fichier FAC_2019_0092-935.png : Date non détectée
# Erreur dans le fichier FAC_2019_0093-965.png : Date non détectée
# Échec pour le fichier FAC_2019_0094-580.png : list index out of range
# Échec pour le fichier FAC_2019_0095-897.png : list index out of range
# Erreur dans le fichier FAC_2019_0096-735.png : Date non détectée
# Erreur dans le fichier FAC_2019_0097-322.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0098-217.png : Date non détectée
# Erreur dans le fichier FAC_2019_0099-671.png : Date non détectée
# Échec pour le fichier FAC_2019_0101-405.png : list index out of range
# Échec pour le fichier FAC_2019_0102-905.png : list index out of range
# Erreur dans le fichier FAC_2019_0103-936.png : Date non détectée
# Erreur dans le fichier FAC_2019_0104-658.png : Date non détectée
# Échec pour le fichier FAC_2019_0105-469.png : list index out of range
# Erreur dans le fichier FAC_2019_0108-142.png : Total mal détecté
# Échec pour le fichier FAC_2019_0110-762.png : list index out of range
# Erreur dans le fichier FAC_2019_0111-574.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0112-551.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0113-269.png : Date non détectée
# Erreur dans le fichier FAC_2019_0114-764.png : Nom non détecté, Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0115-598.png : Nom non détecté, Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0116-438.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2019_0117-919.png : Date non détectée
# Erreur dans le fichier FAC_2019_0118-597.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0119-408.png : Date non détectée
# Erreur dans le fichier FAC_2019_0120-370.png : Nom non détecté, Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0121-224.png : Date non détectée
# Erreur dans le fichier FAC_2019_0122-141.png : Nom non détecté, Date non détectée
# Échec pour le fichier FAC_2019_0123-521.png : list index out of range
# Erreur dans le fichier FAC_2019_0124-505.png : Date non détectée
# Échec pour le fichier FAC_2019_0125-093.png : list index out of range
# Échec pour le fichier FAC_2019_0127-048.png : list index out of range
# Erreur dans le fichier FAC_2019_0128-881.png : Nom non détecté
# Échec pour le fichier FAC_2019_0129-112.png : list index out of range
# Échec pour le fichier FAC_2019_0130-156.png : list index out of range
# Échec pour le fichier FAC_2019_0131-642.png : list index out of range
# Échec pour le fichier FAC_2019_0132-163.png : list index out of range
# Erreur dans le fichier FAC_2019_0134-696.png : Date non détectée
# Erreur dans le fichier FAC_2019_0135-432.png : Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0137-065.png : list index out of range
# Échec pour le fichier FAC_2019_0141-479.png : list index out of range
# Erreur dans le fichier FAC_2019_0142-541.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0143-257.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0144-994.png : Total mal détecté
# Échec pour le fichier FAC_2019_0145-566.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0147-965.png : list index out of range
# Erreur dans le fichier FAC_2019_0148-011.png : Total mal détecté
# Échec pour le fichier FAC_2019_0150-738.png : list index out of range
# Erreur dans le fichier FAC_2019_0151-117.png : Nom non détecté, Total mal détecté
# Échec pour le fichier FAC_2019_0154-549.png : list index out of range
# Erreur dans le fichier FAC_2019_0155-768.png : Nom non détecté
# Échec pour le fichier FAC_2019_0159-348.png : list index out of range
# Erreur dans le fichier FAC_2019_0160-114.png : Total mal détecté
# Échec pour le fichier FAC_2019_0161-300.png : list index out of range
# Échec pour le fichier FAC_2019_0164-464.png : list index out of range
# Erreur dans le fichier FAC_2019_0165-003.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0167-739.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0171-995.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0172-512.png : Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0173-780.png : list index out of range
# Erreur dans le fichier FAC_2019_0174-182.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0175-519.png : Date non détectée
# Erreur dans le fichier FAC_2019_0176-934.png : Date non détectée
# Erreur dans le fichier FAC_2019_0177-108.png : Date non détectée
# Échec pour le fichier FAC_2019_0178-891.png : list index out of range
# Erreur dans le fichier FAC_2019_0179-640.png : Date non détectée
# Échec pour le fichier FAC_2019_0180-305.png : list index out of range
# Échec pour le fichier FAC_2019_0181-861.png : list index out of range
# Échec pour le fichier FAC_2019_0183-519.png : list index out of range
# Échec pour le fichier FAC_2019_0185-203.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0186-156.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0187-382.png : list index out of range
# Erreur dans le fichier FAC_2019_0188-780.png : Date non détectée
# Erreur dans le fichier FAC_2019_0189-165.png : Date non détectée
# Erreur dans le fichier FAC_2019_0190-552.png : Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0191-976.png : list index out of range
# Erreur dans le fichier FAC_2019_0192-797.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0193-944.png : Date non détectée
# Erreur dans le fichier FAC_2019_0194-543.png : Date non détectée
# Erreur dans le fichier FAC_2019_0195-940.png : Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0197-613.png : list index out of range
# Erreur dans le fichier FAC_2019_0198-331.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0199-500.png : Date non détectée
# Erreur dans le fichier FAC_2019_0200-019.png : Date non détectée
# Erreur dans le fichier FAC_2019_0201-114.png : Date non détectée
# Échec pour le fichier FAC_2019_0202-951.png : list index out of range
# Échec pour le fichier FAC_2019_0203-371.png : list index out of range
# Erreur dans le fichier FAC_2019_0204-899.png : Total mal détecté
# Échec pour le fichier FAC_2019_0205-851.png : list index out of range
# Erreur dans le fichier FAC_2019_0206-826.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0207-314.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0208-245.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0209-059.png : Total mal détecté
# Échec pour le fichier FAC_2019_0210-246.png : list index out of range
# Erreur dans le fichier FAC_2019_0211-899.png : Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0212-580.png : list index out of range
# Erreur dans le fichier FAC_2019_0213-969.png : Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0214-080.png : list index out of range
# Erreur dans le fichier FAC_2019_0215-087.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0217-497.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0218-835.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0219-070.png : Total mal détecté
# Échec pour le fichier FAC_2019_0220-778.png : list index out of range
# Échec pour le fichier FAC_2019_0222-784.png : list index out of range
# Erreur dans le fichier FAC_2019_0224-131.png : Nom non détecté, Total mal détecté
# Échec pour le fichier FAC_2019_0226-486.png : list index out of range
# Erreur dans le fichier FAC_2019_0227-969.png : Total mal détecté
# Échec pour le fichier FAC_2019_0228-562.png : list index out of range
# Erreur dans le fichier FAC_2019_0230-271.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0231-540.png : Nom non détecté, Total mal détecté
# Échec pour le fichier FAC_2019_0232-893.png : list index out of range
# Échec pour le fichier FAC_2019_0233-621.png : list index out of range
# Échec pour le fichier FAC_2019_0235-987.png : list index out of range
# Erreur dans le fichier FAC_2019_0236-216.png : Total mal détecté
# Échec pour le fichier FAC_2019_0242-205.png : All arrays must be of the same length
# Erreur dans le fichier FAC_2019_0245-408.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0247-665.png : Total mal détecté
# Échec pour le fichier FAC_2019_0249-448.png : list index out of range
# Erreur dans le fichier FAC_2019_0250-921.png : Nom non détecté
# Échec pour le fichier FAC_2019_0251-529.png : list index out of range
# Erreur dans le fichier FAC_2019_0252-462.png : Total mal détecté
# Échec pour le fichier FAC_2019_0254-253.png : list index out of range
# Échec pour le fichier FAC_2019_0255-230.png : list index out of range
# Erreur dans le fichier FAC_2019_0257-346.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0259-602.png : Nom non détecté
# Échec pour le fichier FAC_2019_0264-007.png : list index out of range
# Échec pour le fichier FAC_2019_0266-724.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0267-646.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0268-060.png : list index out of range
# Erreur dans le fichier FAC_2019_0270-069.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0271-927.png : Nom non détecté
# Échec pour le fichier FAC_2019_0272-032.png : All arrays must be of the same length
# Erreur dans le fichier FAC_2019_0273-880.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0274-338.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0275-072.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0277-243.png : Nom non détecté, Total mal détecté
# Échec pour le fichier FAC_2019_0278-285.png : list index out of range
# Échec pour le fichier FAC_2019_0279-685.png : list index out of range
# Erreur dans le fichier FAC_2019_0280-497.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0282-552.png : Total mal détecté
# Échec pour le fichier FAC_2019_0283-135.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0284-740.png : list index out of range
# Erreur dans le fichier FAC_2019_0285-957.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0286-903.png : Nom non détecté
# Échec pour le fichier FAC_2019_0288-590.png : list index out of range
# Échec pour le fichier FAC_2019_0290-248.png : All arrays must be of the same length
# Erreur dans le fichier FAC_2019_0291-803.png : Total mal détecté
# Échec pour le fichier FAC_2019_0296-096.png : list index out of range
# Erreur dans le fichier FAC_2019_0299-441.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0300-362.png : Nom non détecté, Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0301-433.png : Date non détectée
# Erreur dans le fichier FAC_2019_0302-420.png : Nom non détecté, Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0303-478.png : Date non détectée
# Erreur dans le fichier FAC_2019_0304-884.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0305-746.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2019_0306-055.png : Date non détectée
# Erreur dans le fichier FAC_2019_0307-689.png : Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0308-669.png : list index out of range
# Erreur dans le fichier FAC_2019_0309-661.png : Nom non détecté, Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0310-100.png : list index out of range
# Erreur dans le fichier FAC_2019_0311-062.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0312-412.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2019_0313-745.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0314-347.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0315-819.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0316-882.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2019_0317-111.png : Date non détectée
# Échec pour le fichier FAC_2019_0318-254.png : list index out of range
# Erreur dans le fichier FAC_2019_0319-196.png : Quantités non détectées, Prix non détectés, Total mal détecté
# Échec pour le fichier FAC_2019_0320-194.png : list index out of range
# Erreur dans le fichier FAC_2019_0322-459.png : Quantités non détectées, Prix non détectés, Total mal détecté
# Erreur dans le fichier FAC_2019_0323-143.png : Date non détectée
# Erreur dans le fichier FAC_2019_0324-432.png : Nom non détecté, Date non détectée
# Erreur dans le fichier FAC_2019_0325-187.png : Date non détectée
# Échec pour le fichier FAC_2019_0326-285.png : list index out of range
# Échec pour le fichier FAC_2019_0327-473.png : list index out of range
# Erreur dans le fichier FAC_2019_0328-255.png : Date non détectée
# Erreur dans le fichier FAC_2019_0329-895.png : Date non détectée
# Échec pour le fichier FAC_2019_0330-945.png : list index out of range
# Échec pour le fichier FAC_2019_0331-077.png : list index out of range
# Échec pour le fichier FAC_2019_0333-827.png : list index out of range
# Erreur dans le fichier FAC_2019_0334-882.png : Date non détectée, Total mal détecté
# Erreur dans le fichier FAC_2019_0335-876.png : Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0336-563.png : All arrays must be of the same length
# Erreur dans le fichier FAC_2019_0339-667.png : Date non détectée
# Erreur dans le fichier FAC_2019_0340-553.png : Date non détectée, Total mal détecté
# Échec pour le fichier FAC_2019_0341-856.png : list index out of range
# Erreur dans le fichier FAC_2019_0343-992.png : Nom non détecté
# Échec pour le fichier FAC_2019_0345-948.png : All arrays must be of the same length
# Erreur dans le fichier FAC_2019_0347-869.png : Total mal détecté
# Échec pour le fichier FAC_2019_0348-242.png : list index out of range
# Erreur dans le fichier FAC_2019_0349-170.png : Total mal détecté
# Échec pour le fichier FAC_2019_0350-416.png : list index out of range
# Erreur dans le fichier FAC_2019_0352-492.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0354-885.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0357-060.png : Nom non détecté, Date non détectée
# Échec pour le fichier FAC_2019_0358-168.png : list index out of range
# Erreur dans le fichier FAC_2019_0364-802.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0367-292.png : Total mal détecté
# Échec pour le fichier FAC_2019_0372-802.png : list index out of range
# Erreur dans le fichier FAC_2019_0374-677.png : Total mal détecté
# Échec pour le fichier FAC_2019_0375-735.png : All arrays must be of the same length
# Erreur dans le fichier FAC_2019_0377-158.png : Total mal détecté
# Échec pour le fichier FAC_2019_0378-194.png : list index out of range
# Échec pour le fichier FAC_2019_0379-303.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0382-059.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0384-753.png : list index out of range
# Échec pour le fichier FAC_2019_0386-062.png : list index out of range
# Échec pour le fichier FAC_2019_0387-765.png : list index out of range
# Erreur dans le fichier FAC_2019_0389-058.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0390-051.png : Total mal détecté
# Échec pour le fichier FAC_2019_0391-598.png : list index out of range
# Échec pour le fichier FAC_2019_0392-488.png : list index out of range
# Erreur dans le fichier FAC_2019_0393-514.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0396-543.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0398-058.png : Nom non détecté
# Échec pour le fichier FAC_2019_0399-983.png : list index out of range
# Erreur dans le fichier FAC_2019_0400-520.png : Nom non détecté
# Échec pour le fichier FAC_2019_0405-609.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0406-069.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0407-691.png : list index out of range
# Erreur dans le fichier FAC_2019_0408-882.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0409-240.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0410-413.png : Nom non détecté
# Échec pour le fichier FAC_2019_0411-122.png : list index out of range
# Échec pour le fichier FAC_2019_0416-592.png : list index out of range
# Échec pour le fichier FAC_2019_0417-608.png : list index out of range
# Erreur dans le fichier FAC_2019_0418-040.png : Nom non détecté
# Erreur dans le fichier FAC_2019_0419-634.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0420-083.png : Total mal détecté
# Échec pour le fichier FAC_2019_0421-429.png : list index out of range
# Erreur dans le fichier FAC_2019_0422-673.png : Total mal détecté
# Échec pour le fichier FAC_2019_0423-597.png : list index out of range
# Échec pour le fichier FAC_2019_0424-578.png : list index out of range
# Échec pour le fichier FAC_2019_0425-535.png : list index out of range
# Erreur dans le fichier FAC_2019_0426-323.png : Quantités non détectées, Prix non détectés, Total mal détecté
# Échec pour le fichier FAC_2019_0427-957.png : list index out of range
# Échec pour le fichier FAC_2019_0429-209.png : list index out of range
# Échec pour le fichier FAC_2019_0431-733.png : All arrays must be of the same length
# Échec pour le fichier FAC_2019_0433-244.png : list index out of range
# Erreur dans le fichier FAC_2019_0435-405.png : Nom non détecté, Total mal détecté
# Échec pour le fichier FAC_2019_0436-134.png : list index out of range
# Échec pour le fichier FAC_2019_0437-687.png : list index out of range
# Échec pour le fichier FAC_2019_0441-323.png : list index out of range
# Erreur dans le fichier FAC_2019_0442-951.png : Nom non détecté, Total mal détecté
# Erreur dans le fichier FAC_2019_0443-769.png : Quantités non détectées, Prix non détectés, Total mal détecté
# Échec pour le fichier FAC_2019_0444-958.png : list index out of range
# Erreur dans le fichier FAC_2019_0445-074.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0446-009.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0447-469.png : Total mal détecté
# Erreur dans le fichier FAC_2019_0449-576.png : Nom non détecté
# Échec pour le fichier FAC_2019_0450-102.png : list index out of range
# Erreur dans le fichier FAC_2019_0452-550.png : Date non détectée
#
# ✅ Traitement terminé. Voici les DataFrames finaux :
# Clients :
#       id_client               Nom                         mail birthday
# 0    CLT_234849    Samuel Coleman           gmeyer@example.com     None
# 1    CLT_235337        Bruce Pace         alan46 @example.org:     None
# 2    CLT_173711   David Macdonald           zobnen@example.com     None
# 3    CLT_587979      Mario Benson          julle45@example.org     None
# 4    CLT_756709   Melissa Moreno.           xdunn@example.org,     None
# ..          ...               ...                          ...      ...
# 137  CLT_552366  Sarah Burgess MD            gpena@example.com     None
# 138  CLT_173757    Raymond Waters       Jimmyparks@example.com     None
# 139  CLT_573954   ‘Angela Nguyen.    moralesjeanne@example.com     None
# 140  CLT_258813      James Nguyen           tprice@example.com     None
# 141  CLT_614608       Isaac Baile  aliciapatterson@example.net     None
#
# [142 rows x 4 columns]
# Factures :
#       id_facture                                              texte  \
# 0    FACT_801945   Address 64623 Wright Mills Turnermouth, KS 45555
# 1    FACT_683158  Address 96374 Amanda Dam East Craigfort, FM 73373
# 2    FACT_103513  Address 720 Norman Stravenue Apt. 861 Maysfort...
# 3    FACT_328312            Address PSC 1953, Bax 3013 APO AP 95181
# 4    FACT_123228  Address 4263 Yoder Viaduct Suite 458 North Deb...
# ..           ...                                                ...
# 137  FACT_147702  Address 07718 Elizabeth Stream Suite 663 East ...
# 138  FACT_615672  Address 1938 James Flats Suite 901 Port Kennet...
# 139  FACT_558623  Address 7648 Payne Manor Suite 778 ‘Trevorport...
# 140  FACT_905198         Address 6544 Lopez Flat New Kevin, WI00743
# 141  FACT_344496  Address 2570 Reynolds Parkway South Michael, U...
#
#     date_facturation
# 0         2018-10-17
# 1         2018-12-01
# 2         2018-12-03
# 3         2018-12-14
# 4         2018-12-16
# ..               ...
# 137       2019-07-05
# 138       2019-07-06
# 139       2019-07-07
# 140       2019-07-09
# 141       2019-07-10
#
# [142 rows x 3 columns]
# Produits :
#       Id_produit                                 Nom   Prix
# 0    PROD_252511  Between everybody size conference.  45.70
# 1    PROD_933588   These president network actually.   7.30
# 2    PROD_272088            Statement sort where on.  21.15
# 3    PROD_543504           Clearly treatment for up.  14.49
# 4    PROD_441413        Brother pretty local likely.  78.32
# ..           ...                                 ...    ...
# 253  PROD_413918      Interview actually quite bill.  89.34
# 254  PROD_867235    Professional of indeed security.  24.85
# 255  PROD_134754    Likely million school education.  18.66
# 256  PROD_304697    Business pattern should popular.  23.20
# 257  PROD_387359             High often win account.  12.59
#
# [258 rows x 3 columns]
# Achats :
#       Id_produit   id_client   id_facture quantité
# 0    PROD_252511  CLT_234849  FACT_801945        4
# 1    PROD_933588  CLT_235337  FACT_683158        3
# 2    PROD_272088  CLT_173711  FACT_103513        1
# 3    PROD_543504  CLT_173711  FACT_103513        1
# 4    PROD_441413  CLT_173711  FACT_103513        3
# ..           ...         ...          ...      ...
# 253  PROD_413918  CLT_258813  FACT_905198        4
# 254  PROD_867235  CLT_258813  FACT_905198        1
# 255  PROD_134754  CLT_258813  FACT_905198        4
# 256  PROD_304697  CLT_258813  FACT_905198        1
# 257  PROD_387359  CLT_614608  FACT_344496        1
#
# [258 rows x 4 columns]

# %% [markdown]
# Beaucoup trop d'échec, seulement 140 / 500 correctement lus, en 9 minutes

# %% [markdown]
# # Avec Azure

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes
from msrest.authentication import CognitiveServicesCredentials

import time

# Configuration du client
endpoint = "https://francecentral.api.cognitive.microsoft.com/"
key = "5b3903aa12104b8c9e036e01c9ef6f80"
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))

# Chemin de l'image locale
file = all_files[4499]
chemin = f"../data/files/{file.split('_')[1]}/{file}"
local_image_path = chemin

# Ouvrir l'image
with open(local_image_path, "rb") as image_stream:
    # Appeler l'API OCR
    read_response = computervision_client.read_in_stream(image_stream, raw=True)

    # Récupérer l'ID de l'opération pour vérifier le résultat
    read_operation_location = read_response.headers["Operation-Location"]
    operation_id = read_operation_location.split("/")[-1]

    # Attendre que l'analyse soit terminée
    while True:
        read_result = computervision_client.get_read_result(operation_id)
        if read_result.status not in [OperationStatusCodes.running, OperationStatusCodes.not_started]:
            break
        time.sleep(1)

    # Afficher le texte extrait
    if read_result.status == OperationStatusCodes.succeeded:
        for text_result in read_result.analyze_result.read_results:
            for line in text_result.lines:
                print(line.text)
# Out:
# INVOICE FAC/2024/0220
# Issue date 2024-04-11
# Bill to Deborah Phillips
# Email hardymaurice@example.net
# Brilllling
# Address 3931 Anthony Locks Apt. 747
# Greerborough, WI 45662
# Read create no office.
# 2 x 119.10 Euro
# Themselves individual identify scene.
# 4 x 134.12 Euro
# TOTAL
# 774.68 Euro

# %%
import io
import time
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes
from msrest.authentication import CognitiveServicesCredentials
from PIL import Image
from PIL import Image, ImageOps
import io

from PIL import Image, ImageOps
import io

def add_white_border_to_region(region, img):
    x, y, w, h = region
    img_width, img_height = img.size  # Dimensions de l'image originale

    # Créer une image de fond blanc de la même taille que l'image d'origine
    new_img = Image.new("RGB", (img_width, img_height), (255, 255, 255))  # Image avec fond blanc

    # Recadrer la région d'origine
    region_img = img.crop((x, y, x + w, y + h))

    # Coller la région recadrée au centre de l'image avec fond blanc
    new_x = x
    new_y = y
    new_img.paste(region_img, (new_x, new_y))

    return new_img

def process_image_azure(input_img_path, regions, endpoint, key):
    computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))
    extracted_texts = {}

    try:
        with Image.open(input_img_path) as img:
            img_width, img_height = img.size  # Dimensions de l'image

            for region_name, (x, y, w, h) in regions.items():
                # Ajouter du blanc autour de la région sans changer ses dimensions
                new_img = add_white_border_to_region((x, y, w, h), img)

                # Convertir l'image modifiée en bytes pour l'API OCR
                img_byte_arr = io.BytesIO()
                new_img.save(img_byte_arr, format='PNG')
                img_byte_arr.seek(0)

                # Appel à l'API OCR Azure
                try:
                    read_response = computervision_client.read_in_stream(img_byte_arr, raw=True)
                    operation_location = read_response.headers["Operation-Location"]
                    operation_id = operation_location.split("/")[-1]

                    # Attendre que l'analyse soit terminée
                    while True:
                        read_result = computervision_client.get_read_result(operation_id)
                        if read_result.status not in [OperationStatusCodes.running, OperationStatusCodes.not_started]:
                            break
                        time.sleep(1)

                    # Extraire le texte si l'analyse est réussie
                    if read_result.status == OperationStatusCodes.succeeded:
                        text = "\n".join(line.text for text_result in read_result.analyze_result.read_results for line in text_result.lines)
                        extracted_texts[region_name] = text.strip()
                    else:
                        print(f"Erreur OCR pour la région '{region_name}': {read_result.status}")
                except Exception as e:
                    print(f"Erreur lors de l'appel à l'API OCR pour la région '{region_name}': {e}")

    except Exception as e:
        print(f"Erreur lors de l'ouverture ou du traitement de l'image {input_img_path}: {e}")

    return extracted_texts


# Définition des régions
predefined_regions = {
    "Adresse": (10, 116, 400, 60),
    "Nom": (70, 70, 250, 30),
    "Mail": (55, 100, 250, 20),
    "Date": (105, 45, 250, 30),
    "Products": (20, 180, 400, 350),
    "Quantities_and_prices": (540, 180, 250, 350)
}

# Configuration Azure
endpoint = "https://francecentral.api.cognitive.microsoft.com/"
key = "5b3903aa12104b8c9e036e01c9ef6f80"

# Vérifier que la variable all_files existe
try:
    file = all_files[5000]
    chemin = f"../data/files/{file.split('_')[1]}/{file}"
    extracted_texts = process_image_azure(chemin, predefined_regions, endpoint, key)

    print(f"adresse: {extracted_texts.get('Adresse', '').replace('\n', ' ')}")
    print(f"nom: {extracted_texts.get('Nom', '')}")
    print(f"mail: {extracted_texts.get('Mail', '')}")
    print(f"date: {extracted_texts.get('Date', '')}")
    print(f"products: {[product for product in extracted_texts.get('Products', '').split('\n') if product != 'TOTAL']}")
    print(f"quantities_and_prices: {extracted_texts.get('Quantities_and_prices', '')}")
except NameError:
    print("Erreur : la variable all_files n'est pas définie.")
# Out:
# adresse: Address 3887 Haynes Circle Apt. 995 West Sallyville, WV 87676
# nom: Gary Carrillo
# mail: meredithturner@example.com
# date: 2024-11-06
# products: ['Source edge score their.', 'Teach themselves despite we.', 'Especially environmental through spring.', 'Phone interesting a look.', 'Cost from without stage.']
# quantities_and_prices: 2 x
# 25.04 Euro
# 4 x
# 34.70 Euro
# 1 x
# 12.72 Euro
# 1 x
# 43.49 Euro
# 4 x
# 3.31 Euro
# 258.33 Euro

# %% [markdown]
# Plus efficace mais bien plus lent, trop lent pour utiliser la technique de faire par bout d'image
